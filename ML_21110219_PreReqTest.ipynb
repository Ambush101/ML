# %%
#1
# there will be total of n*k*m multiplications.
# each n rows of the first matrix will be multiplied each m columns of the second matrix, 
# and each row column operation will have k multiplications,therefore n*k*m

# %%
#2
import numpy as np
import time

def multiply_matrices_lists(a, b):
    n = len(a)
    k = len(a[0])
    m = len(b[0])

    result = [[0 for _ in range(m)] for _ in range(n)]

    for i in range(n):
        for j in range(m):
            result[i][j] = sum(a[i][x] * b[x][j] for x in range(k))

    return result

# Multiply matrices using lists of lists
start_time = time.time()
result_lists = multiply_matrices_lists(matrix_a, matrix_b)
end_time = time.time()
print("Result using lists of lists:", result_lists)
print("Time using lists of lists:", end_time - start_time)

matrix_a_np = np.array(matrix_a)
matrix_b_np = np.array(matrix_b)

start_time_np = time.time()
result_np = np.dot(matrix_a_np, matrix_b_np)
end_time_np = time.time()
print("\nResult using NumPy:", result_np)
print("Time using NumPy:", end_time_np - start_time_np)

# %%
#3
#finding the median will involve repeatedly finding the highest and second-highest elements 
#until you reach the middle element.
#A more efficient approach to find the median is to use the "QuickSelect" algorithm, which is an optimization of the QuickSort algorithm. 
#QuickSelect allows us to find the kth smallest element in an unordered list in linear time, on average. 
#The median is the (n/2)th smallest element in a sorted list, so you can use QuickSelect to find it in O(n) time on average.

# %% [markdown]
# #4
#
# 1. Partial derivative of \( f \) with respect to \( x \) (\( \frac{\partial f}{\partial x} \)):
#
# \[ \frac{\partial f}{\partial x} = \frac{(2xy - y^3 \cot(x)) \sin(x) - (x^2y + y^3) \cos(x)}{\sin^2(x)} \]
#
#
# 2. Partial derivative of \( f \) with respect to \( y \) (\( \frac{\partial f}{\partial y} \)):
#
# \[ \frac{\partial f}{\partial y} = \frac{(x^2 + 3y^2) \sin(x) + (x^2y + y^3) \cot(x)}{\sin^2(x)} \]

# %%
#7
students_data = {
    2022: {
        "Branch 1": {
            1: {
                "Roll Number": 1,
                "Name": "N",
                "Marks": {
                    "Maths": 100,
                    "English": 70,
                }
            },
        },
        "Branch 2": {
        }
    },
    2023: {
        "Branch 1": {
        },
        "Branch 2": {
        }
    },
    2024: {
        "Branch 1": {
        },
        "Branch 2": {
        }
    },
    2025: {
        "Branch 1": {
        },
        "Branch 2": {
        }
    }
}

# %%
#9
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.5, 100.1, 0.5)

y1 = x
y2 = x**2
y3 = x**3 / 100
y4 = np.sin(x)
y5 = np.sin(x) / x
y6 = np.log(x)
y7 = np.exp(x)

plt.figure(figsize=(12, 8))

plt.subplot(3, 3, 1)
plt.plot(x, y1)
plt.title('y = x')

plt.subplot(3, 3, 2)
plt.plot(x, y2)
plt.title('y = x^2')

plt.subplot(3, 3, 3)
plt.plot(x, y3)
plt.title('y = x^3 / 100')

plt.subplot(3, 3, 4)
plt.plot(x, y4)
plt.title('y = sin(x)')

plt.subplot(3, 3, 5)
plt.plot(x, y5)
plt.title('y = sin(x) / x')

plt.subplot(3, 3, 6)
plt.plot(x, y6)
plt.title('y = log(x)')

plt.subplot(3, 3, 7)
plt.plot(x, y7)
plt.title('y = e^x')

plt.tight_layout()
plt.show()
